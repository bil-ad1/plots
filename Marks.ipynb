# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
x_p = np.array(["Eng","Math","Phy","Chem"])
y_p = np.array([45,65,55,75])

# %%
pp.bar(x_p,y_p)
pp.xlabel("Subjects")
pp.ylabel("Scores / 100")
pp.plot()
pp.show()

# %%
pp.pie(y_p)
pp.pi
pp.plot()
pp.show()

# %%
yrs= range(1960,1988)

# %%
print(yrs)
# Out:
# range(1960, 1988)

# %%
list(yrs)
# Out:
# [1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987]

# %%
len(yrs)
# Out:
# 28

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
pop = np.array([
44988690,46065231,47198878,48387301,49627623,50917975,52260189,53655789,55102684,56598144,58142060,59734481,61381987,63099406,64905998,66816877,68834326,70958169,73197258,75561131,78054343,80680459,83431605,86285935,89213706,92191510,95215378,98285755])

# %%
len(pop)
# Out:
# 28

# %%
pp.scatter(yrs,pop)
pp.plot()
pp.show()

# %%
pp.bar(yrs,pop)
pp.plot()
pp.show()
